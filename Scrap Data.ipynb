# %%
from bs4 import BeautifulSoup
import urllib
import re

url = "https://www.irealb.com/forums/showthread.php?4522-Jazz-1350-Standards-Individual-Songs&p=12601#post12601"
fp = urllib.request.urlopen(url)
mybytes = fp.read()
mystr = mybytes.decode("latin-1")
soup = BeautifulSoup(mystr)

songs_urls = []
for link in soup.findAll('a', attrs={'href': re.compile("^irealb://")}):
    songs_urls.append(link.get('href'))

# %%
songs_urls[0]
# Out:
# 'irealb://%32%36%2D%32=%43%6F%6C%74%72%61%6E%65%20%4A%6F%68%6E==%4D%65%64%69%75%6D%20%55%70%20%53%77%69%6E%67=%46==%31%72%33%34%4C%62%4B%63%75%37%5A%4C%37%62%44%34%46%5E%37%20%5A%4C%37%46%20%37%2D%43%5A%4C%37%43%20%37%41%5E%5A%4C%37%45%20%37%5E%62%44%5A%4C%37%62%41%42%62%5E%37%20%34%54%5B%41%2A%20%37%5E%41%5A%41%37%4C%5A%44%5E%62%44%5A%4C%37%62%41%20%37%5E%46%5B%41%5D%2A%20%37%43%20%37%2D%47%5A%4C%37%47%20%37%2D%37%20%45%37%4C%20%37%5E%62%47%43%5B%42%2A%5D%2D%37%20%46%37%46%5A%4C%37%43%20%37%5E%41%5A%4C%37%45%20%5E%37%62%44%5A%4C%37%62%41%20%37%5E%62%42%5A%4C%5E%37%58%79%51%43%5A%4C%37%43%37%5E%62%44%7C%4C%5A%45%2D%37%41%7C%51%79%58%37%2D%62%45%7C%51%79%58%37%62%5E%42%5A%4C%37%46%20%37%5E%44%5A%4C%37%41%20%62%37%58%79%51%37%46%20%37%2D%42%5A%4C%37%46%2D%37%20%43%37%4C%37%43%20%37%5E%41%5A%4C%37%45%20%37%5E%44%62%5A%4C%37%62%41%20%37%5E%46%5B%41%2A%5D%20%5A%43%2D%37%20%47%7C%51%79%58%62%5E%37%20%41%62%37%4C%5A%44%62%5E%37%20%45%37%4C%5A%41%5E%37%20%43%37%4C%5A%46%5E%37%20%20%20%5A==%3
# ...

# %%
from pyRealParser import Tune
song_url = songs_urls[0]
my_tune = Tune.parse_ireal_url(song_url)[0]
print(my_tune)
# Out:
# Parsed 26-2
# ...
# Title: 26-2
# Composer: Coltrane John
# Style: Medium Up Swing
# Key: F
# Transpose: None
# Comp style: 0
# BPM: 0
# Repeats: None
# Time signature: 4/4
#
# Chord string:
# *A[T44F^7 Ab7|Db^7 E7|A^7 C7|C-7 F7|Bb^7 Db7|Gb^7 A7|D-7 G7|G-7 C7 ]*A[F^7 Ab7|Db^7 E7|A^7 C7|C-7 F7|Bb^7 Ab7|Db^7 E7|A^7 C7|F^7 ]*B[C-7 F7|E-7 A7|D^7 F7|Bb^7 |Eb-7 |Ab7 |Db^7 |G-7 C7 ]*A[F^7 Ab7|Db^7 E7|A^7 C7|C-7 F7|Bb^7 Ab7|Db^7 E7|A^7 C7|F^7
#
# Flattened measures:
# | F^7Ab7      | Db^7E7      | A^7C7       | C-7F7       |
# | Bb^7Db7     | Gb^7A7      | D-7G7       | G-7C7       |
# | F^7Ab7      | Db^7E7      | A^7C7       | C-7F7       |
# | Bb^7Ab7     | Db^7E7      | A^7C7       | F^7         |
# | C-7F7       | E-7A7       | D^7F7       | Bb^7        |
# | Eb-7        | Ab7         | Db^7        | G-7C7       |
# | F^7Ab7      | Db^7E7      | A^7C7       | C-7F7       |
# | Bb^7Ab7     | Db^7E7      | A^7C7       | F^7         |

# %% [markdown]
# - title: The title
# - composer: The composer
# - style: The style (e.g. 'Swing', 'Bossa', 'Blues' etc.)
# - key: The key (e.g. 'A', 'F#' etc)
# - transpose: How many semitones to transpose
# - comp_style: Accompaniment style (usually empty)
# - bpm: Tempo in BPM (usually empty)
# - repeats: How many repeats (usually empty)
# - time_signature: Time signature as a tuple (e.g. (3,4), (4, 4), (5, 8) etc.)

# %%
print("title: ", my_tune.title)
print("composer: ", my_tune.composer)
print("style: ", my_tune.style)
print("key: ", my_tune.key)
print("transpose: ", my_tune.transpose)
print("comp_style: ", my_tune.comp_style)
print("bpm: ", my_tune.bpm)
print("repeats: ", my_tune.repeats)
print("time_signature: ", my_tune.time_signature)
# Out:
# title:  26-2
# composer:  Coltrane John
# style:  Medium Up Swing
# key:  F
# transpose:  None
# comp_style:  0
# bpm:  0
# repeats:  None
# time_signature:  (4, 4)

# %%
song_meta = {}
song_meta["title"] = my_tune.title
song_meta["composer"] = my_tune.composer
song_meta["style"] = my_tune.style
song_meta["key"] = my_tune.key
song_meta["transpose"] = my_tune.transpose
song_meta["comp_style"] = my_tune.comp_style
song_meta["bpm"] = my_tune.bpm
song_meta["repeats"] = my_tune.repeats
song_meta["time_signature"] = my_tune.time_signature
# Out:
# '26-2'

# %%
songs_meta = []
for song_url in songs_urls:
    my_tune = Tune.parse_ireal_url(song_url)[0]
    song_meta = {}
    song_meta["title"] = my_tune.title
    song_meta["composer"] = my_tune.composer
    song_meta["style"] = my_tune.style
    song_meta["key"] = my_tune.key
    song_meta["transpose"] = my_tune.transpose
    song_meta["comp_style"] = my_tune.comp_style
    song_meta["bpm"] = my_tune.bpm
    song_meta["repeats"] = my_tune.repeats
    song_meta["time_signature"] = my_tune.time_signature
    songs_meta.append(song_meta)
# Out:
# Parsed 26-2
# Parsed 500 Miles High
# Parsed 502 Blues
# Parsed 52nd Street Theme
# Parsed 9.20 Special
# Parsed A Ballad
# Parsed A Beautiful Friendship
# Parsed A Blossom Fell
# Parsed A Certain Smile
# Parsed A Child Is Born
# Parsed A Felicidade
# Parsed A Fine Romance
# Parsed A Flower Is A Lovesome Thing
# Parsed A Foggy Day
# Parsed A Ghost Of A Chance
# Parsed A Kiss To Build A Dream On
# Parsed A Little Tear
# Parsed A Lovely Way To Spend An Evening
# Parsed A Night In Tunisia
# Parsed A Nightingale Sang In Berkeley Square
# Parsed A Pretty Girl Is Like A Melody
# Parsed A Sleepin' Bee
# Parsed A Smooth One
# Parsed A Sound For Sore Ears
# Parsed A Sunday Kind Of Love
# Parsed A Taste Of Honey
# Parsed A Time For Love
# Parsed A Tisket A Tasket
# Parsed A Weaver Of Dreams
# Parsed A Wonderful Day Like Today
# Parsed Ablution
# Parsed Ac-Cent-Tchu-Ate The Positive
# Parsed Across The Alley From The Alamo
# Parsed Adam's Apple
# Parsed Affirmation
# Parsed African Queen, The
# ...

# %%
import pandas as pd
df = pd.DataFrame(songs_meta)
df.head()
# Out:
#                title         composer            style key transpose  \
# 0               26-2    Coltrane John  Medium Up Swing   F      None
# 1     500 Miles High      Corea Chick       Bossa Nova  E-      None
# 2          502 Blues     Rowles Jimmy            Waltz  A-      None
# 3  52nd Street Theme  Monk Thelonious   Up Tempo Swing   C      None
# 4       9.20 Special      Warren Earl     Medium Swing   C      None
#
#   comp_style bpm repeats time_signature
# 0          0   0    None         (4, 4)
# 1          0   0    None         (4, 4)
# 2          0   0    None         (3, 4)
# 3          0   0    None         (4, 4)
# 4          0   0    None         (4, 4)

# %%
from collections import Counter
print("transpose: ", Counter(df["transpose"]))
print("comp_style: ", Counter(df["comp_style"]))
print("repeats: ", Counter(df["repeats"]))
print("time_signature: ", Counter(df["time_signature"]))
print("bpm: ", Counter(df["bpm"]))
print("key: ", Counter(df["key"]))
# Out:
# transpose:  Counter({None: 1510})
# comp_style:  Counter({'0': 1450, 'Jazz-Medium Up Swing': 7, '230': 4, '170': 4, 'Jazz-Medium Up Swing 2': 3, 'Jazz-Latin/Swing': 2, 'Jazz-Bossa Nova': 2, '70': 2, '75': 2, '130': 2, '185': 2, '265': 2, '175': 2, 'Latin-Brazil: Samba': 2, '160': 2, '90': 2, '200': 2, '140': 2, 'Jazz-Medium Swing': 2, 'Jazz-Ballad Even': 2, '180': 2, '195': 2, '110': 2, '150': 2, '210': 2, '115': 2})
# repeats:  Counter({None: 1490, '3': 12, '0': 6, '1': 2})
# time_signature:  Counter({(4, 4): 1393, (3, 4): 104, (6, 4): 7, (5, 4): 3, (6, 8): 3})
# bpm:  Counter({'0': 1490, '160': 6, '200': 2, '280': 2, '161': 2, '100': 2, '60': 2, '185': 2, '360': 1, '120': 1})
# key:  Counter({'F': 261, 'C': 259, 'Eb': 219, 'Bb': 198, 'G': 128, 'Ab': 90, 'C-': 58, 'Db': 42, 'F-': 41, 'D-': 39, 'G-': 31, 'A-': 29, 'D': 25, 'Bb-': 23, 'Eb-': 16, 'E-': 13, 'A': 13, 'B-': 10, 'E': 5, 'B': 4, 'C#-': 3, 'G#-': 2, 'Gb': 1})
